# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('train_data.csv')
X_test = pd.read_csv('test_data.csv')

# %%
df[df.final_price < 400].head(20)
# Out:
#      row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 5         5           MITSUBISHI        Delica             Jeep
# 12       12                LEXUS        GX 470             Jeep
# 24       24                  BMW            X5             Jeep
# 26       26               TOYOTA         Camry            Sedan
# 28       28               TOYOTA    Highlander             Jeep
# 31       31               TOYOTA         Camry            Sedan
# 37       37            CHEVROLET          Volt        Hatchback
# 40       40           VOLKSWAGEN         Jetta            Sedan
# 52       52            CHEVROLET          1500             Jeep
# 54       54                LEXUS       CT 200h        Hatchback
# 75       75               TOYOTA         Prius        Hatchback
# 77       77               SUBARU      Forester             Jeep
# 89       89               TOYOTA         Prius        Hatchback
# 90       90        MERCEDES-BENZ         E 350            Sedan
# ...

# %%
df[df.deal_type == 'For Sale'].final_price.mean()
# Out:
# 6119.694809728849

# %%
df[df.deal_type == 'For Rent'].final_price.mean()
# Out:
# 233.3264331210191
